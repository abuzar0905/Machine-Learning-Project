# %% [markdown]
# <a href="https://colab.research.google.com/github/abuzar0905/Machine-Learning-Project/blob/main/group1project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# test test test

# %% [markdown]
# # Model Implementation

# %% [markdown]
# #Regression Model

# %% [markdown]
# #Decision Tree

# %% [markdown]
# #Random Forest

# %% [markdown]
# #KNN / SVM
